# %% [markdown]
# Se puede acceder a los ejemplos de este notebook en el GitHub de Chempy:
#
# https://github.com/bjodah/chempy

# %%
from chempy import Substance
ferricyanide = Substance.from_formula('Fe(CN)6-3')
ferricyanide.composition == {0: -3, 26: 1, 6: 6, 7: 6}  # 0 for charge 
print(ferricyanide.unicode_name)
# Fe(CN)₆³⁻ 
print(ferricyanide.latex_name + ", " + ferricyanide.html_name)
# Fe(CN)_{6}^{3-}, Fe(CN)<sub>6</sub><sup>3-</sup> 
print('%.3f' % ferricyanide.mass)
#211.955
# Out:
# Fe(CN)₆³⁻
# Fe(CN)_{6}^{3-}, Fe(CN)<sub>6</sub><sup>3-</sup>
# 211.955

# %%
from chempy import balance_stoichiometry  # Main reaction in NASA's booster rockets:
reac, prod = balance_stoichiometry({'NH4ClO4', 'Al'}, {'Al2O3', 'HCl', 'H2O', 'N2'})
from pprint import pprint

pprint(dict(reac))
pprint(dict(prod))
#{'Al2O3': 5, 'H2O': 9, 'HCl': 6, 'N2': 3}
from chempy import mass_fractions
for fractions in map(mass_fractions, [reac, prod]):
    pprint({k: '{0:.3g} wt%'.format(v*100) for k, v in fractions.items()})
# Out:
# {'Al': 10, 'NH4ClO4': 6}
# {'Al2O3': 5, 'H2O': 9, 'HCl': 6, 'N2': 3}
# {'Al': '27.7 wt%', 'NH4ClO4': '72.3 wt%'}
# {'Al2O3': '52.3 wt%', 'H2O': '16.6 wt%', 'HCl': '22.4 wt%', 'N2': '8.62 wt%'}

# %%
from chempy import ReactionSystem  # The rate constants below are arbitrary

rsys = ReactionSystem.from_string("""2 Fe+2 + H2O2 -> 2 Fe+3 + 2 OH-; 42
2 Fe+3 + H2O2 -> 2 Fe+2 + O2 + 2 H+; 17
H+ + OH- -> H2O; 1e10
H2O -> H+ + OH-; 1e-4""")  # "[H2O]" = 1.0 (actually 55.4 at RT)
from chempy.kinetics.ode import get_odesys
odesys, extra = get_odesys(rsys)
from collections import defaultdict
import numpy as np
tout = sorted(np.concatenate((np.linspace(0, 23), np.logspace(-8, 1))))
c0 = defaultdict(float, {'Fe+2': 0.05, 'H2O2': 0.1, 'H2O': 1.0, 'H+': 1e-2, 'OH-': 1e-12})
result = odesys.integrate(tout, c0, atol=1e-12, rtol=1e-14)
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax in axes:
    _ = result.plot(names=[k for k in rsys.substances if k != 'H2O'], ax=ax)
    _ = ax.legend(loc='best', prop={'size': 9})
    _ = ax.set_xlabel('Time')
    _ = ax.set_ylabel('Concentration')
_ = axes[1].set_ylim([1e-13, 1e-1])
_ = axes[1].set_xscale('log')
_ = axes[1].set_yscale('log')
_ = fig.tight_layout()
_ = fig.savefig('examples/kinetics.png', dpi=72)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-aa38dbdd73f3> in <module>
#      23 _ = axes[1].set_yscale('log')
#      24 _ = fig.tight_layout()
# ---> 25 _ = fig.savefig('examples/kinetics.png', dpi=72)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ...

# %%
from chempy import Substance
azucar=Substance.from_formula('C6H12O6')
print(azucar.unicode_name)
# Out:
# C₆H₁₂O₆

# %%
azucar.composition={0: 0, 6: 6, 1: 12, 8: 6}
print(azucar.composition)
# Out:
# {0: 0, 6: 6, 1: 12, 8: 6}

# %%
print(azucar.latex_name)
print(azucar.unicode_name)
# Out:
# C_{6}H_{12}O_{6}
# C₆H₁₂O₆

# %%
print(azucar.mass)
# Out:
# 180.156
